# %% [markdown]
# # first thing for poc is change word into vec, that's make the result easy to get

# %%
# configure for input, modify this to fit u file

input_file = "/home/qin/pockit/data/word2vec_input_jq.txt"
output_file = "/home/qin/pockit/data/word2vec_output.txt"

# %%
## into my pipenv shell and init it
# !cd /home/qin/pockit
#!pipenv install --dev
# !pipenv shell
# !pip install bert_serving_server -i https://pypi.tuna.tsinghua.edu.cn/simple/
# !pip install bert_serving_server -i https://pypi.tuna.tsinghua.edu.cn/simple/
# Out:
# Shell for /home/qin/.local/share/virtualenvs/qin-jCKApmwE already activated.
# No action taken to avoid nested environments.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# ...
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# ...

# %%
# if success we boot the serving which named "word2vec"
# !bert-serving-start -model_dir /home/qin/bert/chinese_L-12_H-768_A-12 -num_worker=4
# Out:
# usage: /home/qin/.local/share/virtualenvs/qin-jCKApmwE/bin/bert-serving-start -model_dir /home/qin/bert/chinese_L-12_H-768_A-12 -num_worker=4
#                  ARG   VALUE
# __________________________________________________
#            ckpt_name = bert_model.ckpt
#          config_name = bert_config.json
#                 cors = *
#                  cpu = False
#           device_map = []
#   fixed_embed_length = False
#                 fp16 = False
#  gpu_memory_fraction = 0.5
#        graph_tmp_dir = None
#     http_max_connect = 10
#            http_port = None
#         mask_cls_sep = False
#       max_batch_size = 256
#          max_seq_len = 25
#            model_dir = /home/qin/bert/chinese_L-12_H-768_A-12
#           num_worker = 4
#        pooling_layer = [-2]
#     pooling_strategy = REDUCE_MEAN
#                 port = 5555
#             port_out = 5556
#        prefetch_size = 10
#  priority_batch_size = 16
# show_tokens_to_client = False
#      tuned_model_dir = None
# ...
